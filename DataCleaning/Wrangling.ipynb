# %% [markdown]
# # Raw Data Wrangling
# - unpacking json files
# - removing redundand columns
# - removing new line characters from the transcript to allow exporting as a csv file

# %%
import json
import os
import pandas as pd
import pymongo
import numpy as np

# %% [markdown]
# ### Downloding data from MongoDB
# As an alternative you can load the json files individually

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

user='read-user'
password='read-user'

uri = f"mongodb+srv://{user}:{password}@nlp-recommend.nylbml2.mongodb.net/"

client = MongoClient(uri, server_api=ServerApi('1'))
                          
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
mydb = client["nlp-recommend"]
collection = mydb["TED-talks"]
collection.count_documents({})
# Out:
# 6099

# %%
rawdb=pd.DataFrame(list(collection.find()))

# %%
rawdb.head()
# Out:
#                         _id  preview             shortenedUrl action  \
# 0  652af294d95841780141bab7    False  https://go.ted.com/6Ryx   None
# 1  652af54dd95841780141bab8    False  https://go.ted.com/6sZX   None
# 2  652af54dd95841780141bab9    False  https://go.ted.com/6yKv   None
# 3  652af54dd95841780141baba    False  https://go.ted.com/6RgH   None
# 4  652af54dd95841780141babb    False  https://go.ted.com/6JLM   None
#
#                                            videoData  \
# 0  {'__typename': 'Video', 'id': '2147', 'slug': ...
# 1  {'__typename': 'Video', 'id': '2683', 'slug': ...
# 2  {'__typename': 'Video', 'id': '91525', 'slug':...
# 3  {'__typename': 'Video', 'id': '101504', 'slug'...
# 4  {'__typename': 'Video', 'id': '14610', 'slug':...
#
#                                       transcriptData  commentsEnabled  \
# 0  {'translation': {'__typename': 'Translation', ...            False
# 1  {'translation': {'__typename': 'Translation', ...            False
# 2  {'translation': {'__typename': 'Translation', ...            False
# 3  {'translation': {'__typename': 'Translation', ...             True
# 4  {'translation': {'__typename': 'Translation', ...            False
#
#    commentsLoggedInOnly talk_id
# 0                 False    2147
# 1                 False    2683
# 2                 False   91525
# 3                  True  101504
# 4                 False   14610

# %% [markdown]
# ### Data transforming: from json to dataframe columns

# %%
#Function to flatten jsons
def json_flatten(data,col):
    db2=pd.DataFrame(data[col].tolist())
    namesList=[f"{col}-{col_changing}" for col_changing in db2.columns]
    db2.columns = namesList
    data=pd.concat([data.drop(col, axis=1), db2], axis=1)
    return data

# %%
#flattening first bunch of columns
transformed=rawdb.copy()
for col in ['videoData','videoData-type','transcriptData','transcriptData-video','transcriptData-video-talkExtras',
           'videoData-topics','videoData-talkExtras','videoData-relatedVideos','videoData-primaryImageSet',
            'videoData-customContentDetails','videoData-speakers','videoData-topics-nodes','videoData-speakers-nodes',
           'videoData-topics-nodes-0']:
    transformed=json_flatten(transformed,col)

# %%
# concatenating the transcript
transformed = transformed.assign(transcript="")
transformed = transformed.assign(transcript_language="")
for index, row in transformed.iterrows():
    text = ""
    language=""
    if row['transcriptData-translation'] is not None:
        language=row['transcriptData-translation']['language']['englishName']
        transformed.at[index, 'transcript_language'] = language
        for paragraph in row['transcriptData-translation']['paragraphs']:
            for cue in paragraph["cues"]:
                text += " " + cue["text"]
        transformed.at[index, 'transcript'] = text
        
transformed['transcript'].loc[0]
# Out:
# ' (Music) (Applause)'

# %%
# dropping columns
transformed=transformed.drop(['transcriptData-translation','videoData-commentsEnabled', 'videoData-commentsLoggedInOnly',
                               'videoData-id','transcriptData-video-id'], axis=1)

# fill in missing jsons and flatting the remaining columns
replace_dict={'__typename': None, 'id': None, 'name': None, 'slug': None}
for i in range(1,31):
    col='videoData-topics-nodes-'+str(i)
    transformed[col] = transformed[col].apply(lambda x: replace_dict if pd.isna(x) else x)
    transformed=json_flatten(transformed,col)

replace_dict={'__typename': None, 'slug': None, 'id': None}
for i in range(0,6):
    col='videoData-relatedVideos-'+str(i)
    transformed[col] = transformed[col].apply(lambda x: replace_dict if pd.isna(x) else x)
    transformed=json_flatten(transformed,col)
    
replace_dict={'__typename': None, 'url': None, 'aspectRatioName': None}
for i in range(0,5):
    col='videoData-primaryImageSet-'+str(i)
    transformed[col] = transformed[col].apply(lambda x: replace_dict if pd.isna(x) else x)
    transformed=json_flatten(transformed,col)
    
replace_dict={'__typename': None, 'photoUrl': None, 'firstname': None, 'middlename': None, 'lastname': None, 'description': None,
 'isLive': False, 'title': None, 'whatOthersSay': None, 'whoTheyAre': None, 'whyListen': None, 'slug': None}
for i in range(0,16):
    col='videoData-speakers-nodes-'+str(i)
    transformed[col] = transformed[col].apply(lambda x: replace_dict if pd.isna(x) else x)
    transformed=json_flatten(transformed,col)

#extracting the external information from videoData-playerData
transformed = transformed.assign(external={})
col='external'
for index, row in transformed.iterrows():
    x=json.loads(row['videoData-playerData'])
    if col in x:
        transformed.at[index, col] = x[col]
        
    else:
        transformed.at[index, col] ={'service': None, 'code': None, 'duration': None, 'start_time': None}
        
transformed=json_flatten(transformed,col)

transformed=transformed.drop(['videoData-playerData'], axis=1)



pd.set_option('display.max_rows', transformed.shape[0]+1)
transformed.loc[0]
# Out:
# _id                                                                     652af294d95841780141bab7
# preview                                                                                    False
# shortenedUrl                                                             https://go.ted.com/6Ryx
# action                                                                                      None
# commentsEnabled                                                                            False
# commentsLoggedInOnly                                                                       False
# talk_id                                                                                     2147
# videoData-__typename                                                                       Video
# videoData-slug                                 aakash_odedra_a_dance_in_a_hurricane_of_paper_...
# videoData-title                                  A dance in a hurricane of paper, wind and light
# videoData-socialTitle                            A dance in a hurricane of paper, wind and light
# videoData-presenterDisplayName                                                     Aakash Odedra
# videoData-internalLanguageCode                                                                en
# videoData-recordedOn                                                                  2014-10-21
# videoData-curatorApproved                                                                   True
# videoData-viewedCount                                                                     950322
# videoData-duration                                                                           580
# videoData-publishedAt                                                       2014-12-05T16:00:35Z
# videoData-description                          Choreographer Aakash Odedra is dyslexic and ha...
# videoData-socialDescription                    Choreographer Aakash Odedra is dyslexic and ha...
# videoData-partnerName                                                                       None
# videoData-videoContext                                                            TEDGlobal 2014
# videoData-audioInternalLanguageCode                                                           en
# videoData-language                                                                            en
# videoData-hasTranslations                                                                   True
# videoData-featured                                                                          True
# videoData-type-__typename                                                            TypeOfVideo
# videoData-type-id                                                                              1
# videoData-type-name                                                               TED Stage Talk
# transcriptData-video-__typename                                                            Video
# transcriptData-video-talkExtras-__typename                                            TalkExtras
# transcriptData-video-talkExtras-footnotes                                                     []
# videoData-topics-__typename                                                      TopicConnection
# videoData-talkExtras-__typename                                                       TalkExtras
# videoData-talkExtras-recommendations                                                          []
# videoData-talkExtras-takeAction                                                               []
# videoData-talkExtras-learnModules                                                             []
# videoData-customContentDetails-__typename                                   CustomContentDetails
# videoData-customContentDetails-partnerName                                                  None
# videoData-speakers-__typename                                              AcmeSpeakerConnection
# videoData-topics-nodes-0-__typename                                                        Topic
# videoData-topics-nodes-0-id                                                                   40
# videoData-topics-nodes-0-name                                                              music
# videoData-topics-nodes-0-slug                                                              music
# transcript                                                                    (Music) (Applause)
# transcript_language                                                                      English
# videoData-topics-nodes-1-__typename                                                        Topic
# videoData-topics-nodes-1-id                                                                   41
# videoData-topics-nodes-1-name                                                        performance
# videoData-topics-nodes-1-slug                                                        performance
# videoData-topics-nodes-2-__typename                                                        Topic
# videoData-topics-nodes-2-id                                                                   94
# videoData-topics-nodes-2-name                                                              dance
# videoData-topics-nodes-2-slug                                                              dance
# videoData-topics-nodes-3-__typename                                                         None
# videoData-topics-nodes-3-id                                                                 None
# videoData-topics-nodes-3-name                                                               None
# videoData-topics-nodes-3-slug                                                               None
# videoData-topics-nodes-4-__typename                                                         None
# videoData-topics-nodes-4-id                                                                 None
# videoData-topics-nodes-4-name                                                               None
# videoData-topics-nodes-4-slug                                                               None
# videoData-topics-nodes-5-__typename                                                         None
# videoData-topics-nodes-5-id                                                                 None
# videoData-topics-nodes-5-name                                                               None
# videoData-topics-nodes-5-slug                                                               None
# videoData-topics-nodes-6-__typename                                                         None
# videoData-topics-nodes-6-id                                                                 None
# videoData-topics-nodes-6-name                                                               None
# videoData-topics-nodes-6-slug                                                               None
# videoData-topics-nodes-7-__typename                                                         None
# videoData-topics-nodes-7-id                                                                 None
# videoData-topics-nodes-7-name                                                               None
# videoData-topics-nodes-7-slug                                                               None
# videoData-topics-nodes-8-__typename                                                         None
# videoData-topics-nodes-8-id                                                                 None
# videoData-topics-nodes-8-name                                                               None
# videoData-topics-nodes-8-slug                                                               None
# videoData-topics-nodes-9-__typename                                                         None
# videoData-topics-nodes-9-id                                                                 None
# videoData-topics-nodes-9-name                                                               None
# videoData-topics-nodes-9-slug                                                               None
# videoData-topics-nodes-10-__typename                                                        None
# videoData-topics-nodes-10-id                                                                None
# videoData-topics-nodes-10-name                                                              None
# videoData-topics-nodes-10-slug                                                              None
# videoData-topics-nodes-11-__typename                                                        None
# videoData-topics-nodes-11-id                                                                None
# videoData-topics-nodes-11-name                                                              None
# videoData-topics-nodes-11-slug                                                              None
# videoData-topics-nodes-12-__typename                                                        None
# videoData-topics-nodes-12-id                                                                None
# videoData-topics-nodes-12-name                                                              None
# videoData-topics-nodes-12-slug                                                              None
# videoData-topics-nodes-13-__typename                                                        None
# videoData-topics-nodes-13-id                                                                None
# videoData-topics-nodes-13-name                                                              None
# videoData-topics-nodes-13-slug                                                              None
# videoData-topics-nodes-14-__typename                                                        None
# videoData-topics-nodes-14-id                                                                None
# videoData-topics-nodes-14-name                                                              None
# videoData-topics-nodes-14-slug                                                              None
# videoData-topics-nodes-15-__typename                                                        None
# videoData-topics-nodes-15-id                                                                None
# videoData-topics-nodes-15-name                                                              None
# videoData-topics-nodes-15-slug                                                              None
# videoData-topics-nodes-16-__typename                                                        None
# videoData-topics-nodes-16-id                                                                None
# videoData-topics-nodes-16-name                                                              None
# videoData-topics-nodes-16-slug                                                              None
# videoData-topics-nodes-17-__typename                                                        None
# videoData-topics-nodes-17-id                                                                None
# videoData-topics-nodes-17-name                                                              None
# videoData-topics-nodes-17-slug                                                              None
# videoData-topics-nodes-18-__typename                                                        None
# videoData-topics-nodes-18-id                                                                None
# videoData-topics-nodes-18-name                                                              None
# videoData-topics-nodes-18-slug                                                              None
# videoData-topics-nodes-19-__typename                                                        None
# videoData-topics-nodes-19-id                                                                None
# videoData-topics-nodes-19-name                                                              None
# videoData-topics-nodes-19-slug                                                              None
# videoData-topics-nodes-20-__typename                                                        None
# videoData-topics-nodes-20-id                                                                None
# videoData-topics-nodes-20-name                                                              None
# videoData-topics-nodes-20-slug                                                              None
# videoData-topics-nodes-21-__typename                                                        None
# videoData-topics-nodes-21-id                                                                None
# videoData-topics-nodes-21-name                                                              None
# videoData-topics-nodes-21-slug                                                              None
# videoData-topics-nodes-22-__typename                                                        None
# videoData-topics-nodes-22-id                                                                None
# videoData-topics-nodes-22-name                                                              None
# videoData-topics-nodes-22-slug                                                              None
# videoData-topics-nodes-23-__typename                                                        None
# videoData-topics-nodes-23-id                                                                None
# videoData-topics-nodes-23-name                                                              None
# videoData-topics-nodes-23-slug                                                              None
# videoData-topics-nodes-24-__typename                                                        None
# videoData-topics-nodes-24-id                                                                None
# videoData-topics-nodes-24-name                                                              None
# videoData-topics-nodes-24-slug                                                              None
# videoData-topics-nodes-25-__typename                                                        None
# videoData-topics-nodes-25-id                                                                None
# videoData-topics-nodes-25-name                                                              None
# videoData-topics-nodes-25-slug                                                              None
# videoData-topics-nodes-26-__typename                                                        None
# videoData-topics-nodes-26-id                                                                None
# videoData-topics-nodes-26-name                                                              None
# videoData-topics-nodes-26-slug                                                              None
# videoData-topics-nodes-27-__typename                                                        None
# videoData-topics-nodes-27-id                                                                None
# videoData-topics-nodes-27-name                                                              None
# videoData-topics-nodes-27-slug                                                              None
# videoData-topics-nodes-28-__typename                                                        None
# videoData-topics-nodes-28-id                                                                None
# videoData-topics-nodes-28-name                                                              None
# videoData-topics-nodes-28-slug                                                              None
# videoData-topics-nodes-29-__typename                                                        None
# videoData-topics-nodes-29-id                                                                None
# videoData-topics-nodes-29-name                                                              None
# videoData-topics-nodes-29-slug                                                              None
# videoData-topics-nodes-30-__typename                                                        None
# videoData-topics-nodes-30-id                                                                None
# videoData-topics-nodes-30-name                                                              None
# videoData-topics-nodes-30-slug                                                              None
# videoData-relatedVideos-0-__typename                                                       Video
# videoData-relatedVideos-0-slug                         the_lxd_in_the_internet_age_dance_evolves
# videoData-relatedVideos-0-id                                                                 786
# videoData-relatedVideos-1-__typename                                                       Video
# videoData-relatedVideos-1-slug                                    pilobolus_a_dance_of_symbiosis
# videoData-relatedVideos-1-id                                                                  24
# videoData-relatedVideos-2-__typename                                                       Video
# videoData-relatedVideos-2-slug                                quixotic_fusion_dancing_with_light
# videoData-relatedVideos-2-id                                                                1464
# videoData-relatedVideos-3-__typename                                                       Video
# videoData-relatedVideos-3-slug                                      kenichi_ebina_my_magic_moves
# videoData-relatedVideos-3-id                                                                 179
# videoData-relatedVideos-4-__typename                                                       Video
# videoData-relatedVideos-4-slug                 aakash_odedra_a_dance_in_a_hurricane_of_paper_...
# videoData-relatedVideos-4-id                                                                2147
# videoData-relatedVideos-5-__typename                                                       Video
# videoData-relatedVideos-5-slug                 joey_alexander_an_11_year_old_prodigy_performs...
# videoData-relatedVideos-5-id                                                                2273
# videoData-primaryImageSet-0-__typename                                                 PhotoSize
# videoData-primaryImageSet-0-url                https://pe.tedcdn.com/images/ted/7473637e6d363...
# videoData-primaryImageSet-0-aspectRatioName                                                  4x3
# videoData-primaryImageSet-1-__typename                                                 PhotoSize
# videoData-primaryImageSet-1-url                https://pe.tedcdn.com/images/ted/3913cb8eb8182...
# videoData-primaryImageSet-1-aspectRatioName                                                 16x9
# videoData-primaryImageSet-2-__typename                                                      None
# videoData-primaryImageSet-2-url                                                             None
# videoData-primaryImageSet-2-aspectRatioName                                                 None
# videoData-primaryImageSet-3-__typename                                                      None
# videoData-primaryImageSet-3-url                                                             None
# videoData-primaryImageSet-3-aspectRatioName                                                 None
# videoData-primaryImageSet-4-__typename                                                      None
# videoData-primaryImageSet-4-url                                                             None
# videoData-primaryImageSet-4-aspectRatioName                                                 None
# videoData-speakers-nodes-0-__typename                                                AcmeSpeaker
# videoData-speakers-nodes-0-photoUrl            https://pe.tedcdn.com/images/ted/8517424f86d3c...
# videoData-speakers-nodes-0-firstname                                                      Aakash
# videoData-speakers-nodes-0-middlename
# videoData-speakers-nodes-0-lastname                                                       Odedra
# videoData-speakers-nodes-0-description                                             Choreographer
# videoData-speakers-nodes-0-isLive                                                           True
# videoData-speakers-nodes-0-title
# videoData-speakers-nodes-0-whatOthersSay       He had that sense of ecstasy, which reaches up...
# videoData-speakers-nodes-0-whoTheyAre          Aakash Odedra sets raw ancient dance forms fro...
# videoData-speakers-nodes-0-whyListen           Based in the UK with a growing international r...
# videoData-speakers-nodes-0-slug                                                    aakash_odedra
# videoData-speakers-nodes-1-__typename                                                       None
# videoData-speakers-nodes-1-photoUrl                                                         None
# videoData-speakers-nodes-1-firstname                                                        None
# videoData-speakers-nodes-1-middlename                                                       None
# videoData-speakers-nodes-1-lastname                                                         None
# videoData-speakers-nodes-1-description                                                      None
# videoData-speakers-nodes-1-isLive                                                          False
# videoData-speakers-nodes-1-title                                                            None
# videoData-speakers-nodes-1-whatOthersSay                                                    None
# videoData-speakers-nodes-1-whoTheyAre                                                       None
# videoData-speakers-nodes-1-whyListen                                                        None
# videoData-speakers-nodes-1-slug                                                             None
# videoData-speakers-nodes-2-__typename                                                       None
# videoData-speakers-nodes-2-photoUrl                                                         None
# videoData-speakers-nodes-2-firstname                                                        None
# videoData-speakers-nodes-2-middlename                                                       None
# videoData-speakers-nodes-2-lastname                                                         None
# videoData-speakers-nodes-2-description                                                      None
# videoData-speakers-nodes-2-isLive                                                          False
# videoData-speakers-nodes-2-title                                                            None
# videoData-speakers-nodes-2-whatOthersSay                                                    None
# videoData-speakers-nodes-2-whoTheyAre                                                       None
# videoData-speakers-nodes-2-whyListen                                                        None
# videoData-speakers-nodes-2-slug                                                             None
# videoData-speakers-nodes-3-__typename                                                       None
# videoData-speakers-nodes-3-photoUrl                                                         None
# videoData-speakers-nodes-3-firstname                                                        None
# videoData-speakers-nodes-3-middlename                                                       None
# videoData-speakers-nodes-3-lastname                                                         None
# videoData-speakers-nodes-3-description                                                      None
# videoData-speakers-nodes-3-isLive                                                          False
# videoData-speakers-nodes-3-title                                                            None
# videoData-speakers-nodes-3-whatOthersSay                                                    None
# videoData-speakers-nodes-3-whoTheyAre                                                       None
# videoData-speakers-nodes-3-whyListen                                                        None
# videoData-speakers-nodes-3-slug                                                             None
# videoData-speakers-nodes-4-__typename                                                       None
# videoData-speakers-nodes-4-photoUrl                                                         None
# videoData-speakers-nodes-4-firstname                                                        None
# videoData-speakers-nodes-4-middlename                                                       None
# videoData-speakers-nodes-4-lastname                                                         None
# videoData-speakers-nodes-4-description                                                      None
# videoData-speakers-nodes-4-isLive                                                          False
# videoData-speakers-nodes-4-title                                                            None
# videoData-speakers-nodes-4-whatOthersSay                                                    None
# videoData-speakers-nodes-4-whoTheyAre                                                       None
# videoData-speakers-nodes-4-whyListen                                                        None
# videoData-speakers-nodes-4-slug                                                             None
# videoData-speakers-nodes-5-__typename                                                       None
# videoData-speakers-nodes-5-photoUrl                                                         None
# videoData-speakers-nodes-5-firstname                                                        None
# videoData-speakers-nodes-5-middlename                                                       None
# videoData-speakers-nodes-5-lastname                                                         None
# videoData-speakers-nodes-5-description                                                      None
# videoData-speakers-nodes-5-isLive                                                          False
# videoData-speakers-nodes-5-title                                                            None
# videoData-speakers-nodes-5-whatOthersSay                                                    None
# videoData-speakers-nodes-5-whoTheyAre                                                       None
# videoData-speakers-nodes-5-whyListen                                                        None
# videoData-speakers-nodes-5-slug                                                             None
# videoData-speakers-nodes-6-__typename                                                       None
# videoData-speakers-nodes-6-photoUrl                                                         None
# videoData-speakers-nodes-6-firstname                                                        None
# videoData-speakers-nodes-6-middlename                                                       None
# videoData-speakers-nodes-6-lastname                                                         None
# videoData-speakers-nodes-6-description                                                      None
# videoData-speakers-nodes-6-isLive                                                          False
# videoData-speakers-nodes-6-title                                                            None
# videoData-speakers-nodes-6-whatOthersSay                                                    None
# videoData-speakers-nodes-6-whoTheyAre                                                       None
# videoData-speakers-nodes-6-whyListen                                                        None
# videoData-speakers-nodes-6-slug                                                             None
# videoData-speakers-nodes-7-__typename                                                       None
# videoData-speakers-nodes-7-photoUrl                                                         None
# videoData-speakers-nodes-7-firstname                                                        None
# videoData-speakers-nodes-7-middlename                                                       None
# videoData-speakers-nodes-7-lastname                                                         None
# videoData-speakers-nodes-7-description                                                      None
# videoData-speakers-nodes-7-isLive                                                          False
# videoData-speakers-nodes-7-title                                                            None
# videoData-speakers-nodes-7-whatOthersSay                                                    None
# videoData-speakers-nodes-7-whoTheyAre                                                       None
# videoData-speakers-nodes-7-whyListen                                                        None
# videoData-speakers-nodes-7-slug                                                             None
# videoData-speakers-nodes-8-__typename                                                       None
# videoData-speakers-nodes-8-photoUrl                                                         None
# videoData-speakers-nodes-8-firstname                                                        None
# videoData-speakers-nodes-8-middlename                                                       None
# videoData-speakers-nodes-8-lastname                                                         None
# videoData-speakers-nodes-8-description                                                      None
# videoData-speakers-nodes-8-isLive                                                          False
# videoData-speakers-nodes-8-title                                                            None
# videoData-speakers-nodes-8-whatOthersSay                                                    None
# videoData-speakers-nodes-8-whoTheyAre                                                       None
# videoData-speakers-nodes-8-whyListen                                                        None
# videoData-speakers-nodes-8-slug                                                             None
# videoData-speakers-nodes-9-__typename                                                       None
# videoData-speakers-nodes-9-photoUrl                                                         None
# videoData-speakers-nodes-9-firstname                                                        None
# videoData-speakers-nodes-9-middlename                                                       None
# videoData-speakers-nodes-9-lastname                                                         None
# videoData-speakers-nodes-9-description                                                      None
# videoData-speakers-nodes-9-isLive                                                          False
# videoData-speakers-nodes-9-title                                                            None
# videoData-speakers-nodes-9-whatOthersSay                                                    None
# videoData-speakers-nodes-9-whoTheyAre                                                       None
# videoData-speakers-nodes-9-whyListen                                                        None
# videoData-speakers-nodes-9-slug                                                             None
# videoData-speakers-nodes-10-__typename                                                      None
# videoData-speakers-nodes-10-photoUrl                                                        None
# videoData-speakers-nodes-10-firstname                                                       None
# videoData-speakers-nodes-10-middlename                                                      None
# videoData-speakers-nodes-10-lastname                                                        None
# videoData-speakers-nodes-10-description                                                     None
# videoData-speakers-nodes-10-isLive                                                         False
# videoData-speakers-nodes-10-title                                                           None
# videoData-speakers-nodes-10-whatOthersSay                                                   None
# videoData-speakers-nodes-10-whoTheyAre                                                      None
# videoData-speakers-nodes-10-whyListen                                                       None
# videoData-speakers-nodes-10-slug                                                            None
# videoData-speakers-nodes-11-__typename                                                      None
# videoData-speakers-nodes-11-photoUrl                                                        None
# videoData-speakers-nodes-11-firstname                                                       None
# videoData-speakers-nodes-11-middlename                                                      None
# videoData-speakers-nodes-11-lastname                                                        None
# videoData-speakers-nodes-11-description                                                     None
# videoData-speakers-nodes-11-isLive                                                         False
# videoData-speakers-nodes-11-title                                                           None
# videoData-speakers-nodes-11-whatOthersSay                                                   None
# videoData-speakers-nodes-11-whoTheyAre                                                      None
# videoData-speakers-nodes-11-whyListen                                                       None
# videoData-speakers-nodes-11-slug                                                            None
# videoData-speakers-nodes-12-__typename                                                      None
# videoData-speakers-nodes-12-photoUrl                                                        None
# videoData-speakers-nodes-12-firstname                                                       None
# videoData-speakers-nodes-12-middlename                                                      None
# videoData-speakers-nodes-12-lastname                                                        None
# videoData-speakers-nodes-12-description                                                     None
# videoData-speakers-nodes-12-isLive                                                         False
# videoData-speakers-nodes-12-title                                                           None
# videoData-speakers-nodes-12-whatOthersSay                                                   None
# videoData-speakers-nodes-12-whoTheyAre                                                      None
# videoData-speakers-nodes-12-whyListen                                                       None
# videoData-speakers-nodes-12-slug                                                            None
# videoData-speakers-nodes-13-__typename                                                      None
# videoData-speakers-nodes-13-photoUrl                                                        None
# videoData-speakers-nodes-13-firstname                                                       None
# videoData-speakers-nodes-13-middlename                                                      None
# videoData-speakers-nodes-13-lastname                                                        None
# videoData-speakers-nodes-13-description                                                     None
# videoData-speakers-nodes-13-isLive                                                         False
# videoData-speakers-nodes-13-title                                                           None
# videoData-speakers-nodes-13-whatOthersSay                                                   None
# videoData-speakers-nodes-13-whoTheyAre                                                      None
# videoData-speakers-nodes-13-whyListen                                                       None
# videoData-speakers-nodes-13-slug                                                            None
# videoData-speakers-nodes-14-__typename                                                      None
# videoData-speakers-nodes-14-photoUrl                                                        None
# videoData-speakers-nodes-14-firstname                                                       None
# videoData-speakers-nodes-14-middlename                                                      None
# videoData-speakers-nodes-14-lastname                                                        None
# videoData-speakers-nodes-14-description                                                     None
# videoData-speakers-nodes-14-isLive                                                         False
# videoData-speakers-nodes-14-title                                                           None
# videoData-speakers-nodes-14-whatOthersSay                                                   None
# videoData-speakers-nodes-14-whoTheyAre                                                      None
# videoData-speakers-nodes-14-whyListen                                                       None
# videoData-speakers-nodes-14-slug                                                            None
# videoData-speakers-nodes-15-__typename                                                      None
# videoData-speakers-nodes-15-photoUrl                                                        None
# videoData-speakers-nodes-15-firstname                                                       None
# videoData-speakers-nodes-15-middlename                                                      None
# videoData-speakers-nodes-15-lastname                                                        None
# videoData-speakers-nodes-15-description                                                     None
# videoData-speakers-nodes-15-isLive                                                         False
# videoData-speakers-nodes-15-title                                                           None
# videoData-speakers-nodes-15-whatOthersSay                                                   None
# videoData-speakers-nodes-15-whoTheyAre                                                      None
# videoData-speakers-nodes-15-whyListen                                                       None
# videoData-speakers-nodes-15-slug                                                            None
# external-service                                                                         YouTube
# external-code                                                                        T49IjKho5y8
# external-duration                                                                          595.0
# external-start_time                                                                          0.0
# Name: 0, dtype: object

# %% [markdown]
# ### Data cleaning

# %%
#current shape
transformed.shape
# Out:
# (6099, 395)

# %%
final_df=transformed.copy()

# %%
# removing new line characters
chars=['\n','\r']
cols=['videoData-speakers-nodes-0-whoTheyAre','videoData-description','videoData-socialDescription','transcript',
      'videoData-speakers-nodes-0-whatOthersSay','videoData-speakers-nodes-1-whoTheyAre']
for col in cols:
    for ch in chars:
        final_df[col] = final_df[col].replace(ch,' ',regex=True)

# %%
#dropping columns with more than 5000 missing values  
for col in final_df.columns:
    nas=final_df[col].isna().sum()
    if nas>5000:
        print(f'{col} has {nas} NAs/6099')
        final_df=final_df.drop([col], axis=1)
# Out:
# action has 6099 NAs/6099
# videoData-partnerName has 5527 NAs/6099
# videoData-customContentDetails-partnerName has 6087 NAs/6099
# videoData-topics-nodes-10-__typename has 5307 NAs/6099
# videoData-topics-nodes-10-id has 5307 NAs/6099
# videoData-topics-nodes-10-name has 5307 NAs/6099
# videoData-topics-nodes-10-slug has 5307 NAs/6099
# videoData-topics-nodes-11-__typename has 5537 NAs/6099
# videoData-topics-nodes-11-id has 5537 NAs/6099
# videoData-topics-nodes-11-name has 5537 NAs/6099
# videoData-topics-nodes-11-slug has 5537 NAs/6099
# videoData-topics-nodes-12-__typename has 5690 NAs/6099
# videoData-topics-nodes-12-id has 5690 NAs/6099
# videoData-topics-nodes-12-name has 5690 NAs/6099
# videoData-topics-nodes-12-slug has 5690 NAs/6099
# videoData-topics-nodes-13-__typename has 5805 NAs/6099
# videoData-topics-nodes-13-id has 5805 NAs/6099
# videoData-topics-nodes-13-name has 5805 NAs/6099
# videoData-topics-nodes-13-slug has 5805 NAs/6099
# videoData-topics-nodes-14-__typename has 5887 NAs/6099
# videoData-topics-nodes-14-id has 5887 NAs/6099
# videoData-topics-nodes-14-name has 5887 NAs/6099
# videoData-topics-nodes-14-slug has 5887 NAs/6099
# videoData-topics-nodes-15-__typename has 5952 NAs/6099
# videoData-topics-nodes-15-id has 5952 NAs/6099
# videoData-topics-nodes-15-name has 5952 NAs/6099
# videoData-topics-nodes-15-slug has 5952 NAs/6099
# videoData-topics-nodes-16-__typename has 5990 NAs/6099
# videoData-topics-nodes-16-id has 5990 NAs/6099
# videoData-topics-nodes-16-name has 5990 NAs/6099
# videoData-topics-nodes-16-slug has 5990 NAs/6099
# videoData-topics-nodes-17-__typename has 6018 NAs/6099
# videoData-topics-nodes-17-id has 6018 NAs/6099
# videoData-topics-nodes-17-name has 6018 NAs/6099
# videoData-topics-nodes-17-slug has 6018 NAs/6099
# videoData-topics-nodes-18-__typename has 6037 NAs/6099
# videoData-topics-nodes-18-id has 6037 NAs/6099
# videoData-topics-nodes-18-name has 6037 NAs/6099
# videoData-topics-nodes-18-slug has 6037 NAs/6099
# videoData-topics-nodes-19-__typename has 6059 NAs/6099
# videoData-topics-nodes-19-id has 6059 NAs/6099
# videoData-topics-nodes-19-name has 6059 NAs/6099
# videoData-topics-nodes-19-slug has 6059 NAs/6099
# videoData-topics-nodes-20-__typename has 6077 NAs/6099
# videoData-topics-nodes-20-id has 6077 NAs/6099
# videoData-topics-nodes-20-name has 6077 NAs/6099
# videoData-topics-nodes-20-slug has 6077 NAs/6099
# videoData-topics-nodes-21-__typename has 6085 NAs/6099
# videoData-topics-nodes-21-id has 6085 NAs/6099
# videoData-topics-nodes-21-name has 6085 NAs/6099
# videoData-topics-nodes-21-slug has 6085 NAs/6099
# videoData-topics-nodes-22-__typename has 6092 NAs/6099
# videoData-topics-nodes-22-id has 6092 NAs/6099
# videoData-topics-nodes-22-name has 6092 NAs/6099
# videoData-topics-nodes-22-slug has 6092 NAs/6099
# videoData-topics-nodes-23-__typename has 6093 NAs/6099
# videoData-topics-nodes-23-id has 6093 NAs/6099
# videoData-topics-nodes-23-name has 6093 NAs/6099
# videoData-topics-nodes-23-slug has 6093 NAs/6099
# videoData-topics-nodes-24-__typename has 6094 NAs/6099
# videoData-topics-nodes-24-id has 6094 NAs/6099
# videoData-topics-nodes-24-name has 6094 NAs/6099
# videoData-topics-nodes-24-slug has 6094 NAs/6099
# videoData-topics-nodes-25-__typename has 6096 NAs/6099
# videoData-topics-nodes-25-id has 6096 NAs/6099
# videoData-topics-nodes-25-name has 6096 NAs/6099
# videoData-topics-nodes-25-slug has 6096 NAs/6099
# videoData-topics-nodes-26-__typename has 6097 NAs/6099
# videoData-topics-nodes-26-id has 6097 NAs/6099
# videoData-topics-nodes-26-name has 6097 NAs/6099
# videoData-topics-nodes-26-slug has 6097 NAs/6099
# videoData-topics-nodes-27-__typename has 6098 NAs/6099
# videoData-topics-nodes-27-id has 6098 NAs/6099
# videoData-topics-nodes-27-name has 6098 NAs/6099
# videoData-topics-nodes-27-slug has 6098 NAs/6099
# videoData-topics-nodes-28-__typename has 6098 NAs/6099
# videoData-topics-nodes-28-id has 6098 NAs/6099
# videoData-topics-nodes-28-name has 6098 NAs/6099
# videoData-topics-nodes-28-slug has 6098 NAs/6099
# videoData-topics-nodes-29-__typename has 6098 NAs/6099
# videoData-topics-nodes-29-id has 6098 NAs/6099
# videoData-topics-nodes-29-name has 6098 NAs/6099
# videoData-topics-nodes-29-slug has 6098 NAs/6099
# videoData-topics-nodes-30-__typename has 6098 NAs/6099
# videoData-topics-nodes-30-id has 6098 NAs/6099
# videoData-topics-nodes-30-name has 6098 NAs/6099
# videoData-topics-nodes-30-slug has 6098 NAs/6099
# videoData-primaryImageSet-3-__typename has 6093 NAs/6099
# videoData-primaryImageSet-3-url has 6093 NAs/6099
# videoData-primaryImageSet-3-aspectRatioName has 6093 NAs/6099
# videoData-primaryImageSet-4-__typename has 6097 NAs/6099
# videoData-primaryImageSet-4-url has 6097 NAs/6099
# videoData-primaryImageSet-4-aspectRatioName has 6097 NAs/6099
# videoData-speakers-nodes-1-__typename has 5774 NAs/6099
# videoData-speakers-nodes-1-photoUrl has 5774 NAs/6099
# videoData-speakers-nodes-1-firstname has 5774 NAs/6099
# videoData-speakers-nodes-1-middlename has 5774 NAs/6099
# videoData-speakers-nodes-1-lastname has 5774 NAs/6099
# videoData-speakers-nodes-1-description has 5774 NAs/6099
# videoData-speakers-nodes-1-title has 5774 NAs/6099
# videoData-speakers-nodes-1-whatOthersSay has 5774 NAs/6099
# videoData-speakers-nodes-1-whoTheyAre has 5774 NAs/6099
# videoData-speakers-nodes-1-whyListen has 5774 NAs/6099
# videoData-speakers-nodes-1-slug has 5774 NAs/6099
# videoData-speakers-nodes-2-__typename has 6040 NAs/6099
# videoData-speakers-nodes-2-photoUrl has 6040 NAs/6099
# videoData-speakers-nodes-2-firstname has 6040 NAs/6099
# videoData-speakers-nodes-2-middlename has 6040 NAs/6099
# videoData-speakers-nodes-2-lastname has 6040 NAs/6099
# videoData-speakers-nodes-2-description has 6040 NAs/6099
# videoData-speakers-nodes-2-title has 6040 NAs/6099
# videoData-speakers-nodes-2-whatOthersSay has 6040 NAs/6099
# videoData-speakers-nodes-2-whoTheyAre has 6040 NAs/6099
# videoData-speakers-nodes-2-whyListen has 6040 NAs/6099
# videoData-speakers-nodes-2-slug has 6040 NAs/6099
# videoData-speakers-nodes-3-__typename has 6083 NAs/6099
# videoData-speakers-nodes-3-photoUrl has 6083 NAs/6099
# videoData-speakers-nodes-3-firstname has 6083 NAs/6099
# videoData-speakers-nodes-3-middlename has 6083 NAs/6099
# videoData-speakers-nodes-3-lastname has 6083 NAs/6099
# videoData-speakers-nodes-3-description has 6083 NAs/6099
# videoData-speakers-nodes-3-title has 6083 NAs/6099
# videoData-speakers-nodes-3-whatOthersSay has 6083 NAs/6099
# videoData-speakers-nodes-3-whoTheyAre has 6083 NAs/6099
# videoData-speakers-nodes-3-whyListen has 6083 NAs/6099
# videoData-speakers-nodes-3-slug has 6083 NAs/6099
# videoData-speakers-nodes-4-__typename has 6088 NAs/6099
# videoData-speakers-nodes-4-photoUrl has 6088 NAs/6099
# videoData-speakers-nodes-4-firstname has 6088 NAs/6099
# videoData-speakers-nodes-4-middlename has 6088 NAs/6099
# videoData-speakers-nodes-4-lastname has 6088 NAs/6099
# videoData-speakers-nodes-4-description has 6088 NAs/6099
# videoData-speakers-nodes-4-title has 6088 NAs/6099
# videoData-speakers-nodes-4-whatOthersSay has 6088 NAs/6099
# videoData-speakers-nodes-4-whoTheyAre has 6088 NAs/6099
# videoData-speakers-nodes-4-whyListen has 6088 NAs/6099
# videoData-speakers-nodes-4-slug has 6088 NAs/6099
# videoData-speakers-nodes-5-__typename has 6093 NAs/6099
# videoData-speakers-nodes-5-photoUrl has 6093 NAs/6099
# videoData-speakers-nodes-5-firstname has 6093 NAs/6099
# videoData-speakers-nodes-5-middlename has 6093 NAs/6099
# videoData-speakers-nodes-5-lastname has 6093 NAs/6099
# videoData-speakers-nodes-5-description has 6093 NAs/6099
# videoData-speakers-nodes-5-title has 6093 NAs/6099
# videoData-speakers-nodes-5-whatOthersSay has 6093 NAs/6099
# videoData-speakers-nodes-5-whoTheyAre has 6093 NAs/6099
# videoData-speakers-nodes-5-whyListen has 6093 NAs/6099
# videoData-speakers-nodes-5-slug has 6093 NAs/6099
# videoData-speakers-nodes-6-__typename has 6094 NAs/6099
# videoData-speakers-nodes-6-photoUrl has 6094 NAs/6099
# videoData-speakers-nodes-6-firstname has 6094 NAs/6099
# videoData-speakers-nodes-6-middlename has 6094 NAs/6099
# videoData-speakers-nodes-6-lastname has 6094 NAs/6099
# videoData-speakers-nodes-6-description has 6094 NAs/6099
# videoData-speakers-nodes-6-title has 6094 NAs/6099
# videoData-speakers-nodes-6-whatOthersSay has 6094 NAs/6099
# videoData-speakers-nodes-6-whoTheyAre has 6094 NAs/6099
# videoData-speakers-nodes-6-whyListen has 6094 NAs/6099
# videoData-speakers-nodes-6-slug has 6094 NAs/6099
# videoData-speakers-nodes-7-__typename has 6094 NAs/6099
# videoData-speakers-nodes-7-photoUrl has 6094 NAs/6099
# videoData-speakers-nodes-7-firstname has 6094 NAs/6099
# videoData-speakers-nodes-7-middlename has 6094 NAs/6099
# videoData-speakers-nodes-7-lastname has 6094 NAs/6099
# videoData-speakers-nodes-7-description has 6094 NAs/6099
# videoData-speakers-nodes-7-title has 6094 NAs/6099
# videoData-speakers-nodes-7-whatOthersSay has 6094 NAs/6099
# videoData-speakers-nodes-7-whoTheyAre has 6094 NAs/6099
# videoData-speakers-nodes-7-whyListen has 6094 NAs/6099
# videoData-speakers-nodes-7-slug has 6094 NAs/6099
# videoData-speakers-nodes-8-__typename has 6094 NAs/6099
# videoData-speakers-nodes-8-photoUrl has 6094 NAs/6099
# videoData-speakers-nodes-8-firstname has 6094 NAs/6099
# videoData-speakers-nodes-8-middlename has 6094 NAs/6099
# videoData-speakers-nodes-8-lastname has 6094 NAs/6099
# videoData-speakers-nodes-8-description has 6094 NAs/6099
# videoData-speakers-nodes-8-title has 6094 NAs/6099
# videoData-speakers-nodes-8-whatOthersSay has 6094 NAs/6099
# videoData-speakers-nodes-8-whoTheyAre has 6094 NAs/6099
# videoData-speakers-nodes-8-whyListen has 6094 NAs/6099
# videoData-speakers-nodes-8-slug has 6094 NAs/6099
# videoData-speakers-nodes-9-__typename has 6094 NAs/6099
# videoData-speakers-nodes-9-photoUrl has 6094 NAs/6099
# videoData-speakers-nodes-9-firstname has 6094 NAs/6099
# videoData-speakers-nodes-9-middlename has 6094 NAs/6099
# videoData-speakers-nodes-9-lastname has 6094 NAs/6099
# videoData-speakers-nodes-9-description has 6094 NAs/6099
# videoData-speakers-nodes-9-title has 6094 NAs/6099
# videoData-speakers-nodes-9-whatOthersSay has 6094 NAs/6099
# videoData-speakers-nodes-9-whoTheyAre has 6094 NAs/6099
# videoData-speakers-nodes-9-whyListen has 6094 NAs/6099
# videoData-speakers-nodes-9-slug has 6094 NAs/6099
# videoData-speakers-nodes-10-__typename has 6095 NAs/6099
# videoData-speakers-nodes-10-photoUrl has 6095 NAs/6099
# videoData-speakers-nodes-10-firstname has 6095 NAs/6099
# videoData-speakers-nodes-10-middlename has 6095 NAs/6099
# videoData-speakers-nodes-10-lastname has 6095 NAs/6099
# videoData-speakers-nodes-10-description has 6095 NAs/6099
# videoData-speakers-nodes-10-title has 6095 NAs/6099
# videoData-speakers-nodes-10-whatOthersSay has 6095 NAs/6099
# videoData-speakers-nodes-10-whoTheyAre has 6095 NAs/6099
# videoData-speakers-nodes-10-whyListen has 6095 NAs/6099
# videoData-speakers-nodes-10-slug has 6095 NAs/6099
# videoData-speakers-nodes-11-__typename has 6095 NAs/6099
# videoData-speakers-nodes-11-photoUrl has 6095 NAs/6099
# videoData-speakers-nodes-11-firstname has 6095 NAs/6099
# videoData-speakers-nodes-11-middlename has 6095 NAs/6099
# videoData-speakers-nodes-11-lastname has 6095 NAs/6099
# videoData-speakers-nodes-11-description has 6095 NAs/6099
# videoData-speakers-nodes-11-title has 6095 NAs/6099
# videoData-speakers-nodes-11-whatOthersSay has 6095 NAs/6099
# videoData-speakers-nodes-11-whoTheyAre has 6095 NAs/6099
# videoData-speakers-nodes-11-whyListen has 6095 NAs/6099
# videoData-speakers-nodes-11-slug has 6095 NAs/6099
# videoData-speakers-nodes-12-__typename has 6095 NAs/6099
# videoData-speakers-nodes-12-photoUrl has 6095 NAs/6099
# videoData-speakers-nodes-12-firstname has 6095 NAs/6099
# videoData-speakers-nodes-12-middlename has 6095 NAs/6099
# videoData-speakers-nodes-12-lastname has 6095 NAs/6099
# videoData-speakers-nodes-12-description has 6095 NAs/6099
# videoData-speakers-nodes-12-title has 6095 NAs/6099
# videoData-speakers-nodes-12-whatOthersSay has 6095 NAs/6099
# videoData-speakers-nodes-12-whoTheyAre has 6095 NAs/6099
# videoData-speakers-nodes-12-whyListen has 6095 NAs/6099
# videoData-speakers-nodes-12-slug has 6095 NAs/6099
# videoData-speakers-nodes-13-__typename has 6097 NAs/6099
# videoData-speakers-nodes-13-photoUrl has 6097 NAs/6099
# videoData-speakers-nodes-13-firstname has 6097 NAs/6099
# videoData-speakers-nodes-13-middlename has 6097 NAs/6099
# videoData-speakers-nodes-13-lastname has 6097 NAs/6099
# videoData-speakers-nodes-13-description has 6097 NAs/6099
# videoData-speakers-nodes-13-title has 6097 NAs/6099
# videoData-speakers-nodes-13-whatOthersSay has 6097 NAs/6099
# videoData-speakers-nodes-13-whoTheyAre has 6097 NAs/6099
# videoData-speakers-nodes-13-whyListen has 6097 NAs/6099
# videoData-speakers-nodes-13-slug has 6097 NAs/6099
# videoData-speakers-nodes-14-__typename has 6098 NAs/6099
# videoData-speakers-nodes-14-photoUrl has 6098 NAs/6099
# videoData-speakers-nodes-14-firstname has 6098 NAs/6099
# videoData-speakers-nodes-14-middlename has 6098 NAs/6099
# videoData-speakers-nodes-14-lastname has 6098 NAs/6099
# videoData-speakers-nodes-14-description has 6098 NAs/6099
# videoData-speakers-nodes-14-title has 6098 NAs/6099
# videoData-speakers-nodes-14-whatOthersSay has 6098 NAs/6099
# videoData-speakers-nodes-14-whoTheyAre has 6098 NAs/6099
# videoData-speakers-nodes-14-whyListen has 6098 NAs/6099
# videoData-speakers-nodes-14-slug has 6098 NAs/6099
# videoData-speakers-nodes-15-__typename has 6098 NAs/6099
# videoData-speakers-nodes-15-photoUrl has 6098 NAs/6099
# videoData-speakers-nodes-15-firstname has 6098 NAs/6099
# videoData-speakers-nodes-15-middlename has 6098 NAs/6099
# videoData-speakers-nodes-15-lastname has 6098 NAs/6099
# videoData-speakers-nodes-15-description has 6098 NAs/6099
# videoData-speakers-nodes-15-title has 6098 NAs/6099
# videoData-speakers-nodes-15-whatOthersSay has 6098 NAs/6099
# videoData-speakers-nodes-15-whoTheyAre has 6098 NAs/6099
# videoData-speakers-nodes-15-whyListen has 6098 NAs/6099
# videoData-speakers-nodes-15-slug has 6098 NAs/6099

# %%
#finding duplicated columns or columns with same data
from itertools import combinations

[(i, j) for i,j in combinations(final_df, 2) if final_df[i].equals(final_df[j])]
# Out:
# [('preview', 'videoData-speakers-nodes-15-isLive'),
#  ('videoData-__typename', 'transcriptData-video-__typename'),
#  ('videoData-internalLanguageCode', 'videoData-language'),
#  ('transcriptData-video-talkExtras-__typename',
#   'videoData-talkExtras-__typename'),
#  ('videoData-speakers-nodes-6-isLive', 'videoData-speakers-nodes-7-isLive'),
#  ('videoData-speakers-nodes-6-isLive', 'videoData-speakers-nodes-8-isLive'),
#  ('videoData-speakers-nodes-7-isLive', 'videoData-speakers-nodes-8-isLive'),
#  ('videoData-speakers-nodes-10-isLive', 'videoData-speakers-nodes-12-isLive'),
#  ('videoData-speakers-nodes-13-isLive', 'videoData-speakers-nodes-14-isLive')]

# %%
# dropping first list of redundant columns
drop1=['videoData-__typename', 'transcriptData-video-__typename','transcriptData-video-talkExtras-__typename', 
       'videoData-internalLanguageCode','videoData-relatedVideos-5-__typename','videoData-relatedVideos-4-__typename',
       'videoData-relatedVideos-3-__typename','videoData-relatedVideos-2-__typename','videoData-relatedVideos-1-__typename',
       'videoData-topics-nodes-1-__typename','videoData-topics-nodes-2-__typename','videoData-topics-nodes-3-__typename',
       'videoData-topics-nodes-4-__typename','videoData-topics-nodes-5-__typename','videoData-topics-nodes-6-__typename',
       'videoData-topics-nodes-7-__typename','videoData-topics-nodes-8-__typename','videoData-topics-nodes-9-__typename',
       'videoData-customContentDetails-__typename','videoData-talkExtras-__typename']
for col in drop1:
    final_df=final_df.drop([col], axis=1)

# %%
final_df.shape
# Out:
# (6099, 116)

# %%
final_df.loc[0]
# Out:
# _id                                                                     652af294d95841780141bab7
# preview                                                                                    False
# shortenedUrl                                                             https://go.ted.com/6Ryx
# commentsEnabled                                                                            False
# commentsLoggedInOnly                                                                       False
# talk_id                                                                                     2147
# videoData-slug                                 aakash_odedra_a_dance_in_a_hurricane_of_paper_...
# videoData-title                                  A dance in a hurricane of paper, wind and light
# videoData-socialTitle                            A dance in a hurricane of paper, wind and light
# videoData-presenterDisplayName                                                     Aakash Odedra
# videoData-recordedOn                                                                  2014-10-21
# videoData-curatorApproved                                                                   True
# videoData-viewedCount                                                                     950322
# videoData-duration                                                                           580
# videoData-publishedAt                                                       2014-12-05T16:00:35Z
# videoData-description                          Choreographer Aakash Odedra is dyslexic and ha...
# videoData-socialDescription                    Choreographer Aakash Odedra is dyslexic and ha...
# videoData-videoContext                                                            TEDGlobal 2014
# videoData-audioInternalLanguageCode                                                           en
# videoData-language                                                                            en
# videoData-hasTranslations                                                                   True
# videoData-featured                                                                          True
# videoData-type-__typename                                                            TypeOfVideo
# videoData-type-id                                                                              1
# videoData-type-name                                                               TED Stage Talk
# transcriptData-video-talkExtras-footnotes                                                     []
# videoData-topics-__typename                                                      TopicConnection
# videoData-talkExtras-recommendations                                                          []
# videoData-talkExtras-takeAction                                                               []
# videoData-talkExtras-learnModules                                                             []
# videoData-speakers-__typename                                              AcmeSpeakerConnection
# videoData-topics-nodes-0-__typename                                                        Topic
# videoData-topics-nodes-0-id                                                                   40
# videoData-topics-nodes-0-name                                                              music
# videoData-topics-nodes-0-slug                                                              music
# transcript                                                                    (Music) (Applause)
# videoData-topics-nodes-1-id                                                                   41
# videoData-topics-nodes-1-name                                                        performance
# videoData-topics-nodes-1-slug                                                        performance
# videoData-topics-nodes-2-id                                                                   94
# videoData-topics-nodes-2-name                                                              dance
# videoData-topics-nodes-2-slug                                                              dance
# videoData-topics-nodes-3-id                                                                 None
# videoData-topics-nodes-3-name                                                               None
# videoData-topics-nodes-3-slug                                                               None
# videoData-topics-nodes-4-id                                                                 None
# videoData-topics-nodes-4-name                                                               None
# videoData-topics-nodes-4-slug                                                               None
# videoData-topics-nodes-5-id                                                                 None
# videoData-topics-nodes-5-name                                                               None
# videoData-topics-nodes-5-slug                                                               None
# videoData-topics-nodes-6-id                                                                 None
# videoData-topics-nodes-6-name                                                               None
# videoData-topics-nodes-6-slug                                                               None
# videoData-topics-nodes-7-id                                                                 None
# videoData-topics-nodes-7-name                                                               None
# videoData-topics-nodes-7-slug                                                               None
# videoData-topics-nodes-8-id                                                                 None
# videoData-topics-nodes-8-name                                                               None
# videoData-topics-nodes-8-slug                                                               None
# videoData-topics-nodes-9-id                                                                 None
# videoData-topics-nodes-9-name                                                               None
# videoData-topics-nodes-9-slug                                                               None
# videoData-relatedVideos-0-__typename                                                       Video
# videoData-relatedVideos-0-slug                         the_lxd_in_the_internet_age_dance_evolves
# videoData-relatedVideos-0-id                                                                 786
# videoData-relatedVideos-1-slug                                    pilobolus_a_dance_of_symbiosis
# videoData-relatedVideos-1-id                                                                  24
# videoData-relatedVideos-2-slug                                quixotic_fusion_dancing_with_light
# videoData-relatedVideos-2-id                                                                1464
# videoData-relatedVideos-3-slug                                      kenichi_ebina_my_magic_moves
# videoData-relatedVideos-3-id                                                                 179
# videoData-relatedVideos-4-slug                 aakash_odedra_a_dance_in_a_hurricane_of_paper_...
# videoData-relatedVideos-4-id                                                                2147
# videoData-relatedVideos-5-slug                 joey_alexander_an_11_year_old_prodigy_performs...
# videoData-relatedVideos-5-id                                                                2273
# videoData-primaryImageSet-0-__typename                                                 PhotoSize
# videoData-primaryImageSet-0-url                https://pe.tedcdn.com/images/ted/7473637e6d363...
# videoData-primaryImageSet-0-aspectRatioName                                                  4x3
# videoData-primaryImageSet-1-__typename                                                 PhotoSize
# videoData-primaryImageSet-1-url                https://pe.tedcdn.com/images/ted/3913cb8eb8182...
# videoData-primaryImageSet-1-aspectRatioName                                                 16x9
# videoData-primaryImageSet-2-__typename                                                      None
# videoData-primaryImageSet-2-url                                                             None
# videoData-primaryImageSet-2-aspectRatioName                                                 None
# videoData-speakers-nodes-0-__typename                                                AcmeSpeaker
# videoData-speakers-nodes-0-photoUrl            https://pe.tedcdn.com/images/ted/8517424f86d3c...
# videoData-speakers-nodes-0-firstname                                                      Aakash
# videoData-speakers-nodes-0-middlename
# videoData-speakers-nodes-0-lastname                                                       Odedra
# videoData-speakers-nodes-0-description                                             Choreographer
# videoData-speakers-nodes-0-isLive                                                           True
# videoData-speakers-nodes-0-title
# videoData-speakers-nodes-0-whatOthersSay       He had that sense of ecstasy, which reaches up...
# videoData-speakers-nodes-0-whoTheyAre          Aakash Odedra sets raw ancient dance forms fro...
# videoData-speakers-nodes-0-whyListen           Based in the UK with a growing international r...
# videoData-speakers-nodes-0-slug                                                    aakash_odedra
# videoData-speakers-nodes-1-isLive                                                          False
# videoData-speakers-nodes-2-isLive                                                          False
# videoData-speakers-nodes-3-isLive                                                          False
# videoData-speakers-nodes-4-isLive                                                          False
# videoData-speakers-nodes-5-isLive                                                          False
# videoData-speakers-nodes-6-isLive                                                          False
# videoData-speakers-nodes-7-isLive                                                          False
# videoData-speakers-nodes-8-isLive                                                          False
# videoData-speakers-nodes-9-isLive                                                          False
# videoData-speakers-nodes-10-isLive                                                         False
# videoData-speakers-nodes-11-isLive                                                         False
# videoData-speakers-nodes-12-isLive                                                         False
# videoData-speakers-nodes-13-isLive                                                         False
# videoData-speakers-nodes-14-isLive                                                         False
# videoData-speakers-nodes-15-isLive                                                         False
# external-service                                                                         YouTube
# external-code                                                                        T49IjKho5y8
# external-duration                                                                          595.0
# external-start_time                                                                          0.0
# Name: 0, dtype: object

# %% [markdown]
# #### Remaining to unpack:
# - transcriptData-video-talkExtras-footnotes
# - videoData-talkExtras-recommendations
# - videoData-talkExtras-takeAction
# - videoData-talkExtras-learnModules
#
# #### Steps to do:
# - renaming columns,
# - dropping redundant columns

# %%
final_df.to_csv('dataset_v22-10-2023.csv')

# %%
final_df['transcript'].loc[271]
# Out:
# ' Την παρουσίαση που έκανα εδώ πριν δύο χρόνια την έχω κάνει άλλες 2.000 φορές. Σήμερα το πρωί θα σας κάνω μια μικρή παρουσίαση που κάνω για πρώτη φορά, έτσι.. λοιπόν είναι  - δεν επιθυμώ να ανεβάσω τον πήχη αντιθέτως προσπαθώ να τον χαμηλώσω Διότι ετοίμασα αυτή την παρουσίαση, προκειμένου να αντιμετωπίσω  την πρόκληση αυτού του συνεδρίου Και η φανταστική παρουσίαση  της Κάρεν Άρμστρονγκ μου θύμησε ότι η θρησκεία όταν  την αντιλαμβανόμαστε σωστά δεν έχει να κάνει με την πίστη,  αλλά με τη συμπεριφορά. Πιθανώς θα πρέπει να λέμε το ίδιο  σχετικά με την έννοια της αισιοδοξίας Πώς τολμούμε να είμαστε αισιόδοξοι; Η αισιοδοξία μερικές φορές χαρακτηρίζεται  ως μία πίστη, μία διανοητική κατάσταση Όπως ο Μαχάτμα Γκάντι συνήθιζε να λέει «Πρέπει να γίνεις ο ίδιος η αλλαγή  που θέλεις να δεις στον κόσμο» Και το αποτέλεσμα για το οποίο θέλουμε να είμαστε αισιόδοξοι  δεν θα δημιουργηθεί από την πίστη και μόνο, εκτός  εάν αν βρεθούμε στο σημείο όπου η πίστη θα φέρει μία νέου είδους συμπεριφορά.  Αλλά η λέξη «συμπεριφορά» νομίζω, κάποιες φορές παρερμηνεύεται είμαι μεγάλος υποστηρικτής να αλλάζουμε τις λάμπες και να αγοράζουμε υβριδικά και η Τίππερ και εγώ βάλαμε  33 ηλιακούς συσσωρευτές στο σπίτι μας και έσκαψα και γεωθερμικά πηγάδια,  και έκανα και όλα αυτά. Αλλά όσο και σημαντικό  κι αν είναι να αλλάξουμε τις λάμπες είναι πιο σημαντικό να αλλάξουμε  τους σχετικούς νόμους. Και όταν αλλάζουμε τη συμπεριφορά μας  στην καθημερινή μας ζωή μερικές φορές αφήνουμε  εκτός το κομμάτι του πολίτη και το δημοκρατικό κομμάτι.  Προκειμένου να είμαστε αισιόδοξοι για αυτό πρέπει να είμαστε τρομερά δραστήριοι σαν πολίτες της δημοκρατίας μας. Προκειμένου να λύσουμε  την κλιματική κρίση, θα πρέπει να λύσουμε  την κρίση δημοκρατίας. Και περνάμε μία (κρίση). Προσπαθώ εδώ και πολύ καιρό  να πω αυτήν την ιστορία. Μου το θύμισε αυτό πρόσφατα μία γυναίκα που πέρασε μπροστά  από το τραπέζι στο οποίο καθόμουν, και με κοιτούσε καθώς περνούσε.  Ήταν στα 70... έδειχνε ότι είχε ευγενικό πρόσωπο.  Δεν μου πέρασε κάτι από το μυαλό μέχρι που είδα από την άκρη του ματιού μου ότι περπατούσε  από την αντίθετη κατεύθυνση, εξακολουθώντας να με κοιτάζει.  Και έτσι είπα, «Τι κάνετε;» Και απάντησε, «Ξέρετε,  εάν βάψετε τα μαλλιά σας μαύρα, θα ήσασταν ίδιος ο Αλ Γκορ».  (Γέλια) Πολλά χρόνια πριν,  όταν ήμουν ένα νέο μέλος του κογκρέσου, πέρασα πολύ χρόνο ασχολούμενος  με την πρόκληση του ελέγχου πυρηνικών όπλων -  των ανταγωνισμό των πυρηνικών όπλων. Και οι πολεμικοί ιστορικοί μου έμαθαν εκείνη την περίδο ότι οι πολεμικές  συγκρούσεις ανήκουν συνήθως σε τρεις κατηγορίες: τοπικές μάχες, περιφερειακοί ή τοπικοί πόλεμοι,  και οι σπάνιοι αλλά πολύ σημαντικοί παγκόσμιοι πόλεμοι. Στρατηγικές διαμάχες. Και κάθε επίπεδο πολέμου  απαιτεί διαφορετική κατανομή πόρων διαφορετική προσέγγιση, διαφορετικό μοντέλο οργάνωσης. Οι περιβαλλοντικές προκλήσεις  ανήκουν επίσης στις ίδιες κατηγορίες, και τα περισσότερα  από αυτά που σκεπτόμαστε είναι τοπικά περιβαλλοντικά προβλήματα:  μόλυνση του αέρα, του νερού, επικίνδυνοι σκουπιδότοποι.  Αλλά επίσης μπορεί να είναι περιφερειακά περιβαλλοντικά προβλήματα,  όπως η όξινη βροχή από τα μεσοδυτικά στα μεσανατολικά,  και από τη Δυτική Ευρώπη στην Αρκτική,  και από τις μεσοδυτικές περιοχές πέρα του Μισισίπι προς τη νεκρή ζώνη  του κόλπου του Μεξικού. Και υπάρχουν πολλές από αυτές.  Αλλά η κλιματική κρίση είναι μία σπάνια αλλά πολύ σημαντική παγκόσμια, ή στρατηγική, σύγκρουση. Τα πάντα επηρεάζονται. Και πρέπει  να οργανώσουμε την απάντησή μας με τον σωστό τρόπο. Πρέπει,  παγκόσμια, να παρακινήσουμε τον κόσμο σε ανανεώσιμη ενέργεια,  διατήρηση, αποδοτικότητα και σε παγκόσμια μετάβαση  σε χαμηλού άνθρακα οικονομία. Έχουμε δουλειά! Και πρέπει  να κινητοποιήσουμε τους πόρους και την πολιτική θέληση.  Αλλά η πολιτική θέληση πρέπει να κινηθεί προκειμένου  να κινητοποιηθούν οι πόροι Να σας δείξω αυτές τις διαφάνειες εδώ. Νόμιζα ότι θα ξεκινούσα με το λογότυπο.  Αυτό που λείπει εδώ, φυσικά, είναι οι βόρειοι πολικοί πάγοι. Η Γροιλανδία παραμένει.  28 χρόνια πριν, έτσι ήτα ...
