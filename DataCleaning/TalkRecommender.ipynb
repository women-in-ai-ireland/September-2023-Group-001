# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
filename='fulldataset_v28-10-2023.csv'
dataset=pd.read_csv(filename)

# %%
dataset.shape
# Out:
# (6099, 64)

# %%
dataset.describe()
# Out:
#              talk_id   view_counts  duration_in_seconds  video_type_id  \
# count    6099.000000  6.099000e+03          6099.000000    6099.000000
# mean    31922.899000  2.170442e+06           705.598951       2.131005
# std     35786.142263  3.800615e+06           524.620001       1.551051
# min         1.000000  4.540000e+02            60.000000       1.000000
# 25%      1766.500000  6.986540e+05           349.000000       1.000000
# 50%     16985.000000  1.422268e+06           674.000000       1.000000
# 75%     62743.000000  2.203588e+06           917.000000       3.000000
# max    118894.000000  7.574498e+07         20404.000000       9.000000
#
#         topic_0_id   topic_1_id   topic_2_id   topic_3_id   topic_4_id  \
# count  6099.000000  6080.000000  5946.000000  5471.000000  4816.000000
# mean     23.396622    60.454276   150.612344   252.375251   417.820390
# std      31.346882   144.599024   529.905398   759.366644  1090.406153
# min       3.000000     4.000000     5.000000     6.000000     8.000000
# 25%       6.000000    13.000000    44.000000    62.000000    81.000000
# 50%       8.000000    51.500000    71.000000   100.000000   165.000000
# 75%      37.000000    72.000000   133.000000   206.000000   273.000000
# max     294.000000  5800.000000  6394.000000  6865.000000  7089.000000
#
#         topic_5_id   topic_6_id   topic_7_id  related_talk_0_id  \
# count  3896.000000  3063.000000  2224.000000        6094.000000
# mean    607.200462   750.905322   872.768885       21039.839678
# std    1380.353942  1541.386511  1658.387048       30064.743170
# min       9.000000    10.000000    15.000000           1.000000
# 25%     105.000000   148.000000   175.000000        1004.000000
# 50%     212.000000   246.000000   273.000000        2533.000000
# 75%     341.000000   424.500000   525.000000       31587.500000
# max    7188.000000  7188.000000  7188.000000      118136.000000
#
#        related_talk_1_id  related_talk_2_id  related_talk_3_id  \
# count        6089.000000        6068.000000        5099.000000
# mean        21078.973559       20677.036585        9132.671308
# std         29818.939827       29176.865919       13672.886362
# min             1.000000           1.000000           3.000000
# 25%          1085.000000        1193.000000        1052.000000
# 50%          2558.000000        2586.000000        1930.000000
# 75%         30821.000000       30813.000000       13247.000000
# max        117687.000000      117489.000000       49424.000000
#
#        related_talk_4_id  related_talk_5_id
# count        5098.000000        5097.000000
# mean         9589.487250        9797.675103
# std         13920.517765       14055.937641
# min             2.000000           3.000000
# 25%          1155.250000        1169.000000
# 50%          2052.000000        2066.000000
# 75%         17849.500000       19413.000000
# max         49424.000000       49424.000000

# %%
pd.set_option('display.max_rows', dataset.shape[0]+1)
dataset.loc[1]
# Out:
# mongodb_id                                          652af54dd95841780141bab8
# has_preview                                                            False
# shortened_url                                        https://go.ted.com/6sZX
# comments_enabled                                                       False
# comments_logged_in_only                                                False
# talk_id                                                                 2683
# talk_slug                  aala_el_khani_what_it_s_like_to_be_a_parent_in...
# talk_title                       What it's like to be a parent in a war zone
# talk_social_title                What it's like to be a parent in a war zone
# speakers_name                                                  Aala El-Khani
# recorded_on                                                       2016-02-14
# curator_approved                                                        True
# view_counts                                                          1237721
# duration_in_seconds                                                      846
# published_timestamp                                     2017-02-10T15:49:37Z
# talk_description           How do parents protect their children and help...
# talk_social_description    How do parents protect their children and help...
# video_context                                                 TEDxManchester
# video_audio_language                                                      en
# video_data_language                                                       en
# has_translations                                                        True
# is_featured                                                             True
# video_type_id                                                              2
# video_type_name                                                    TEDx Talk
# video_speakers_typename                                AcmeSpeakerConnection
# topic_0_id                                                                74
# topic_0_name                                                      psychology
# transcript                  Worldwide, over 1.5 billion people experience...
# transcript_language                                                  English
# topic_1_id                                                              86.0
# topic_1_name                                                   communication
# topic_2_id                                                              87.0
# topic_2_name                                                       community
# topic_3_id                                                             100.0
# topic_3_name                                                       parenting
# topic_4_id                                                             105.0
# topic_4_name                                                             war
# topic_5_id                                                             180.0
# topic_5_name                                                natural disaster
# topic_6_id                                                             198.0
# topic_6_name                                                        violence
# topic_7_id                                                             199.0
# topic_7_name                                                        humanity
# related_talk_0_slug        anders_fjellberg_two_nameless_bodies_washed_up...
# related_talk_0_id                                                     2353.0
# related_talk_1_slug        melissa_fleming_a_boat_carrying_500_refugees_s...
# related_talk_1_id                                                     2358.0
# related_talk_2_slug        alexander_betts_our_refugee_system_is_failing_...
# related_talk_2_id                                                     2449.0
# related_talk_3_slug        luma_mufleh_don_t_feel_sorry_for_refugees_beli...
# related_talk_3_id                                                     2809.0
# related_talk_4_slug        melanie_nezer_the_fundamental_right_to_seek_as...
# related_talk_4_id                                                    45969.0
# related_talk_5_slug        muhammed_idris_what_refugees_need_to_start_new...
# related_talk_5_id                                                    36063.0
# speakers_typename                                                AcmeSpeaker
# speakers_firstname                                                      Aala
# speakers_lastname                                                   El-Khani
# speakers_description                               Humanitarian psychologist
# speakers_is_live                                                        True
# speakers_who_they_are      Aala El-Khani explores the needs of families a...
# speakers_why_listen        <p>Dr. Aala El-Khani researches and develops i...
# external_service                                                     YouTube
# external_service_code                                            dY9f9bFctUE
# Name: 1, dtype: object

# %% [markdown]
# ### Filtering the dataset to transcripts in 'English'

# %%
dataset[dataset['transcript_language']=='English'].shape
# Out:
# (4959, 64)

# %%
datasetEng=dataset[dataset['transcript_language']=='English'].reset_index()

datasetEng.to_csv('..\DatasetEnglish.csv', index=False)

# %% [markdown]
# ### Exploring the distribution by topic, duration & across time

# %%
datasetEng['published_date']=pd.to_datetime(datasetEng['published_timestamp']).dt.date

y=datasetEng['published_date'].value_counts(sort=False)
y.index=pd.to_datetime(y.index)

fig, ax = plt.subplots()
ax.plot_date(y.index,y.values)
ax.set(title = "Frequency of TED talks with English transcripts, across time",
       xlabel = "Year",
       ylabel = "Counts of TED talks")
fig.autofmt_xdate()
plt.show()

# %%
topic0=datasetEng['topic_0_name'].value_counts()
fig=plt.subplots(figsize =(10, 7))
topic0[topic0.values>10].plot(kind='bar', xlabel="Topic", ylabel="Counts",title="Frequency of main topics (over 10 counts)")
# Out:
# <AxesSubplot:title={'center':'Frequency of main topics (over 10 counts)'}, xlabel='Topic', ylabel='Counts'>

# %%
fig=plt.subplots(figsize =(10, 7))
topic0[topic0.values<=10].plot(kind='bar', xlabel="Topic", ylabel="Counts",title="Frequency of main topics (under 10 counts)")
# Out:
# <AxesSubplot:title={'center':'Frequency of main topics (under 10 counts)'}, xlabel='Topic', ylabel='Counts'>

# %%
import matplotlib.ticker as ticker #I will use tickers to cluster months for readability

datasetEng['published_year']=pd.to_datetime(datasetEng['published_timestamp']).dt.year
time_topic=datasetEng[['published_year', 'topic_0_name']].loc[datasetEng['topic_0_name'].isin(topic0[topic0.values>30].index.to_list())].value_counts(sort=False).unstack()
plt.figure(figsize=(40, 30)) 
ax = time_topic.plot(kind='bar',stacked=True, colormap='tab20')
ax.set_xlabel("Date") 
ax.set_ylabel("Counts") 
ax.set_title("Frequency of main topics by time")
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.gcf().autofmt_xdate()

plt.show()

# %%
#topic0.index.to_list()
science=['science', 'technology', 'invention', 'math', 'engineering', 'software', 'computers', 'innovation', 'statistics', 'data', 'AI','robots', 'future','space', 'Internet',
        'astronomy']
culture=['culture', 'creativity', 'music', 'art', 'philosophy','performance', 'poetry', 'architecture','dance','film', 'comedy', 'history', 'language', 'paleontology',  
         'urban planning','entertainment']
social=['global issues','social change','politics', 'corruption','military', 'terrorism', 'crime','poverty', 'war','depression','philanthropy', 'religion','violence', 'women', 
        'gender', 'Africa', 'activism']
health=['health', 'disease', 'health care', 'genetics', 'DNA', 'brain', 'mental health', 'cancer', 'cognitive science', 'memory', 'death']
business=['cities', 'business', 'entrepreneur', 'economics', 'marketing', 'leadership', 'success', 'interview','work', 'law']
nature=['climate change', 'environment', 'sustainability', 'animals', 'nature', 'natural disaster', 'biodiversity', 'biology', 'water', 'evolution']
education =['education','psychology', 'relationships', 'communication', 'storytelling', 'collaboration', 'media', 'TED Fellows', 'motivation','parenting', 'community', 
            'personal growth', 'self', 'library']
other=['design',  'empathy', 'fear', 'humor',  'happiness', 'sports', 'flight', 'TEDx', 'love','food','transportation','time', 'exploration', 'universe', 'illusion']

# %%
def plot_topic(lista, type_topic):
    datasetEng['published_year']=pd.to_datetime(datasetEng['published_timestamp']).dt.year
    time_topic=datasetEng[['published_year', 'topic_0_name']].loc[datasetEng['topic_0_name'].isin(lista)].value_counts(sort=False).unstack()
    plt.figure(figsize=(40, 30)) 
    ax = time_topic.plot(kind='bar',stacked=True, colormap='tab20')
    ax.set_xlabel("Date") 
    ax.set_ylabel("Counts") 
    ax.set_title(f"Frequency of main {type_topic} topics by time")
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.gcf().autofmt_xdate()
    plt.show()

# %%
plot_topic(science, 'Science and Technology')

# %%
plot_topic(culture, 'Arts and Culture')

# %%
plot_topic(social, 'Social Issues and Change')

# %%
plot_topic(health, 'Health and Medicine')

# %%
plot_topic(business, 'Business and Entrepreneurship')

# %%
plot_topic(nature, 'Nature and Environment')

# %%
plot_topic(education, 'Education')

# %%
plot_topic(other, 'Miscellaneous')

# %%
y=datasetEng['duration_in_seconds'].value_counts()
fig, ax = plt.subplots()
ax.scatter(y.index,y.values)
ax.set(title = "Frequency of TED talks with English transcripts by duration",xlabel = "Duration in second",ylabel = "Counts of TED talks")
plt.show()

# %%
import seaborn as sns
x=datasetEng['duration_in_seconds']/60
h=datasetEng['topic_0_name'].apply(lambda x: 'Science and Technology' if x in science else ('Arts and Culture' if x in culture else 
                                                                                            ('Social Issues and Change' if x in social else 
                                                                                             ('Health and Medicine' if x in health else 
                                                                                              ('Business and Entrepreneurship' if x in business else 
                                                                                               ('Nature and Environment' if x in nature else 
                                                                                                ('Education' if x in education else 
                                                                                                 ('Miscellaneous' if x in other else 'other'))))))))

plt.figure(figsize=(10, 6))
ax=sns.scatterplot(x=x, y=datasetEng['published_date'], hue=h)
ax.set(title = "TED talks duration by time",xlabel = "Duration in minutes",ylabel = "Time in years")
ax.invert_yaxis()
plt.show()

# %%
plot_data=datasetEng[['duration_in_seconds','published_date','topic_0_name']].copy()
plot_data['duration_in_minutes']=plot_data['duration_in_seconds']/60
plot_data['topics']=plot_data['topic_0_name'].apply(lambda x: 'Science and Technology' if x in science else ('Arts and Culture' if x in culture else 
                                                                                            ('Social Issues and Change' if x in social else 
                                                                                             ('Health and Medicine' if x in health else 
                                                                                              ('Business and Entrepreneurship' if x in business else 
                                                                                               ('Nature and Environment' if x in nature else 
                                                                                                ('Education' if x in education else 
                                                                                                 ('Miscellaneous' if x in other else 'other'))))))))
#plot_data=plot_data.drop(['topic_0_name', 'duration_in_seconds'], axis=1)

plot_data['year'] = pd.to_datetime(plot_data['published_date']).dt.year

# Group by 'topics' and 'year', calculate mean duration and get counts
grouped_data = plot_data.groupby(['topics', 'year']).agg({'duration_in_minutes': 'mean'}).rename(columns={'duration_in_minutes': 'mean_duration_in_minutes'})

# Calculate counts of each group
grouped_data['counts'] = plot_data.groupby(['topics', 'year']).size()

# %%
grouped_data.reset_index(drop=True,inplace=True)
plt.figure(figsize=(10, 5))
ax = sns.scatterplot(x='mean_duration_in_minutes', y='year', hue='topics', size='counts', sizes=(20, 200), data=grouped_data)
ax.set(title = "TED talks duration by time", xlabel = "Average Duration in Minutes", ylabel = "Year")
#ax.invert_yaxis()
sns.color_palette("rocket", as_cmap=True)
grouped_data['year'] = grouped_data['year'].astype(int)
years = range(min(grouped_data['year']), max(grouped_data['year'])+1, 2)

ax.set_yticks(years)
ax.set_yticklabels(years)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jm/hgnb9xq10vqdsz83bftglvp80000gn/T/ipykernel_7737/2225026341.py in <module>
#       1 grouped_data.reset_index(drop=True,inplace=True)
#       2 plt.figure(figsize=(10, 5))
# ----> 3 ax = sns.scatterplot(x='mean_duration_in_minutes', y='year', hue='topics', size='counts', sizes=(20, 200), data=grouped_data)
#       4 ax.set(title = "TED talks duration by time", xlabel = "Average Duration in Minutes", ylabel = "Year")
#       5 #ax.invert_yaxis()
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
#     809         data=data, variables=variables,
#     810         x_bins=x_bins, y_bins=y_bins,
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     901
#     902                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903                 raise ValueError(err)
#     904
#     905             else:
#
# ValueError: Could not interpret value `year` for parameter `y`

# %%
datasetEng.head()
# Out:
#    index                mongodb_id  has_preview            shortened_url  \
# 0      0  652af294d95841780141bab7        False  https://go.ted.com/6Ryx
# 1      1  652af54dd95841780141bab8        False  https://go.ted.com/6sZX
# 2      2  652af54dd95841780141bab9        False  https://go.ted.com/6yKv
# 3      3  652af54dd95841780141baba        False  https://go.ted.com/6RgH
# 4      4  652af54dd95841780141babb        False  https://go.ted.com/6JLM
#
#    comments_enabled  comments_logged_in_only  talk_id  \
# 0             False                    False     2147
# 1             False                    False     2683
# 2             False                    False    91525
# 3              True                     True   101504
# 4             False                    False    14610
#
#                                            talk_slug  \
# 0  aakash_odedra_a_dance_in_a_hurricane_of_paper_...
# 1  aala_el_khani_what_it_s_like_to_be_a_parent_in...
# 2  aarathi_krishnan_5_ethical_principles_for_digi...
# 3  aaron_bastani_a_socialist_perspective_on_the_p...
# 4  aaron_duffy_lake_buckley_and_jack_foster_illus...
#
#                                           talk_title  \
# 0    A dance in a hurricane of paper, wind and light
# 1        What it's like to be a parent in a war zone
# 2  5 ethical principles for digitizing humanitari...
# 3  A socialist perspective on the pursuit of happ...
# 4                   "Illusions for a better society"
#
#                                  talk_social_title  ... speakers_firstname  \
# 0  A dance in a hurricane of paper, wind and light  ...             Aakash
# 1      What it's like to be a parent in a war zone  ...               Aala
# 2                                              NaN  ...            Aarathi
# 3                                              NaN  ...              Aaron
# 4                 "Illusions for a better society"  ...              Aaron
#
#   speakers_lastname            speakers_description  speakers_is_live  \
# 0            Odedra                   Choreographer              True
# 1          El-Khani       Humanitarian psychologist              True
# 2          Krishnan  Tech and human rights ethicist              True
# 3           Bastani                      Journalist              True
# 4             Duffy                             NaN             False
#
#                                speakers_who_they_are  \
# 0  Aakash Odedra sets raw ancient dance forms fro...
# 1  Aala El-Khani explores the needs of families a...
# 2  Aarathi Krishnan designs institutions and syst...
# 3  Aaron Bastani covers the issues that will defi...
# 4  Aaron Duffy began employing visual tricks into...
#
#                                  speakers_why_listen external_service  \
# 0  Based in the UK with a growing international r...          YouTube
# 1  <p>Dr. Aala El-Khani researches and develops i...          YouTube
# 2  <p>Aarathi Krishnan works at the intersections...          YouTube
# 3  <div>Aaron Bastani is the cofounder of Novara ...          YouTube
# 4                                                NaN              NaN
#
#   external_service_code published_date published_year
# 0           T49IjKho5y8     2014-12-05           2014
# 1           dY9f9bFctUE     2017-02-10           2017
# 2           Ix8Cz-veat4     2022-06-14           2022
# 3           M6aq2SH-xVo     2023-01-20           2023
# 4                   NaN     2018-04-14           2018
#
# [5 rows x 67 columns]

# %%
datasetEng.shape
dataE = datasetEng.copy()

# %%
# Let's combine the title and the details of the talk.
dataE['details'] = dataE['talk_title'] + ' ' + dataE['transcript']

# %%
dataE.head()
# Out:
#    index                mongodb_id  has_preview            shortened_url  \
# 0      0  652af294d95841780141bab7        False  https://go.ted.com/6Ryx
# 1      1  652af54dd95841780141bab8        False  https://go.ted.com/6sZX
# 2      2  652af54dd95841780141bab9        False  https://go.ted.com/6yKv
# 3      3  652af54dd95841780141baba        False  https://go.ted.com/6RgH
# 4      4  652af54dd95841780141babb        False  https://go.ted.com/6JLM
#
#    comments_enabled  comments_logged_in_only  talk_id  \
# 0             False                    False     2147
# 1             False                    False     2683
# 2             False                    False    91525
# 3              True                     True   101504
# 4             False                    False    14610
#
#                                            talk_slug  \
# 0  aakash_odedra_a_dance_in_a_hurricane_of_paper_...
# 1  aala_el_khani_what_it_s_like_to_be_a_parent_in...
# 2  aarathi_krishnan_5_ethical_principles_for_digi...
# 3  aaron_bastani_a_socialist_perspective_on_the_p...
# 4  aaron_duffy_lake_buckley_and_jack_foster_illus...
#
#                                           talk_title  \
# 0    A dance in a hurricane of paper, wind and light
# 1        What it's like to be a parent in a war zone
# 2  5 ethical principles for digitizing humanitari...
# 3  A socialist perspective on the pursuit of happ...
# 4                   "Illusions for a better society"
#
#                                  talk_social_title  ... speakers_lastname  \
# 0  A dance in a hurricane of paper, wind and light  ...            Odedra
# 1      What it's like to be a parent in a war zone  ...          El-Khani
# 2                                              NaN  ...          Krishnan
# 3                                              NaN  ...           Bastani
# 4                 "Illusions for a better society"  ...             Duffy
#
#              speakers_description  speakers_is_live  \
# 0                   Choreographer              True
# 1       Humanitarian psychologist              True
# 2  Tech and human rights ethicist              True
# 3                      Journalist              True
# 4                             NaN             False
#
#                                speakers_who_they_are  \
# 0  Aakash Odedra sets raw ancient dance forms fro...
# 1  Aala El-Khani explores the needs of families a...
# 2  Aarathi Krishnan designs institutions and syst...
# 3  Aaron Bastani covers the issues that will defi...
# 4  Aaron Duffy began employing visual tricks into...
#
#                                  speakers_why_listen external_service  \
# 0  Based in the UK with a growing international r...          YouTube
# 1  <p>Dr. Aala El-Khani researches and develops i...          YouTube
# 2  <p>Aarathi Krishnan works at the intersections...          YouTube
# 3  <div>Aaron Bastani is the cofounder of Novara ...          YouTube
# 4                                                NaN              NaN
#
#   external_service_code published_date published_year  \
# 0           T49IjKho5y8     2014-12-05           2014
# 1           dY9f9bFctUE     2017-02-10           2017
# 2           Ix8Cz-veat4     2022-06-14           2022
# 3           M6aq2SH-xVo     2023-01-20           2023
# 4                   NaN     2018-04-14           2018
#
#                                              details
# 0  A dance in a hurricane of paper, wind and ligh...
# 1  What it's like to be a parent in a war zone  W...
# 2  5 ethical principles for digitizing humanitari...
# 3  A socialist perspective on the pursuit of happ...
# 4  "Illusions for a better society"  Narrator: We...
#
# [5 rows x 68 columns]

# %%
# Removing the unnecessary information
dataE = dataE[['speakers_name', 'details']]
dataE.dropna(inplace = True)
dataE.head()
# Out:
# /var/folders/jm/hgnb9xq10vqdsz83bftglvp80000gn/T/ipykernel_7737/2001385610.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataE.dropna(inplace = True)
#                                speakers_name  \
# 0                              Aakash Odedra
# 1                              Aala El-Khani
# 2                           Aarathi Krishnan
# 3                              Aaron Bastani
# 4  Aaron Duffy, Lake Buckley and Jack Foster
#
#                                              details
# 0  A dance in a hurricane of paper, wind and ligh...
# 1  What it's like to be a parent in a war zone  W...
# 2  5 ethical principles for digitizing humanitari...
# 3  A socialist perspective on the pursuit of happ...
# 4  "Illusions for a better society"  Narrator: We...

# %%
dataE.shape
# Out:
# (4958, 2)

# %%
def remove_stopwords(text):
    stop_words = stopwords.words('english')
    
    imp_words = []

# Storing the important words
    for word in str(text).split():
        word = word.lower()
        
        if word not in stop_words:
            imp_words.append(word)

    output = " ".join(imp_words)

    return output

# %%
dataE['details'] = dataE['details'].apply(lambda text: remove_stopwords(text))
dataE.head()
# Out:
#                                speakers_name  \
# 0                              Aakash Odedra
# 1                              Aala El-Khani
# 2                           Aarathi Krishnan
# 3                              Aaron Bastani
# 4  Aaron Duffy, Lake Buckley and Jack Foster
#
#                                              details
# 0  dance hurricane paper, wind light (music) (app...
# 1  like parent war zone worldwide, 1.5 billion pe...
# 2  5 ethical principles digitizing humanitarian a...
# 3  socialist perspective pursuit happiness allow ...
# 4  "illusions better society" narrator: today spe...

# %%
import nltk
import string
import warnings
from scipy.stats import pearsonr
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
 
nltk.download('stopwords')
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sherin/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
punctuations_list = string.punctuation
 
 
def cleaning_punctuations(text):
    signal = str.maketrans('', '', punctuations_list)
    return text.translate(signal)
 
 
dataE['details'] = dataE['details'].apply(lambda x: cleaning_punctuations(x))
dataE.head()
# Out:
#                                speakers_name  \
# 0                              Aakash Odedra
# 1                              Aala El-Khani
# 2                           Aarathi Krishnan
# 3                              Aaron Bastani
# 4  Aaron Duffy, Lake Buckley and Jack Foster
#
#                                              details
# 0    dance hurricane paper wind light music applause
# 1  like parent war zone worldwide 15 billion peop...
# 2  5 ethical principles digitizing humanitarian a...
# 3  socialist perspective pursuit happiness allow ...
# 4  illusions better society narrator today specif...

# %%
details_corpus = " ".join(dataE['details'])
 
plt.figure(figsize=(20, 20))
wc = WordCloud(max_words=1000, 
               width=800,
               height=400).generate(details_corpus)
plt.axis('off')
plt.imshow(wc)
plt.show()

# %%
# %%capture
vectorizer = TfidfVectorizer(analyzer = 'word')
vectorizer.fit(dataE['details'])

# %%
def get_similarities(talk_content, data=dataE):

    # Getting vector for the input talk_content.
    talk_array1 = vectorizer.transform(talk_content).toarray()

    # We will store similarity for each row of the dataset.
    sim = []
    pea = []
    for idx, row in data.iterrows():
        details = row['details']

        # Getting vector for current talk.
        talk_array2 = vectorizer.transform(data[data['details'] == details]['details']).toarray()

        # Calculating cosine similarities
        cos_sim = cosine_similarity(talk_array1, talk_array2)[0][0]

        # Calculating pearson correlation
        pea_sim = pearsonr(talk_array1.squeeze(), talk_array2.squeeze())[0]

        sim.append(cos_sim)
        pea.append(pea_sim)

    return sim, pea

# %%
def recommend_talks(talk_content, data=dataE):

    data['cos_sim'], data['pea_sim'] = get_similarities(talk_content)

    data.sort_values(by=['cos_sim', 'pea_sim'], ascending=[
                    False, False], inplace=True)

    display(data[['speakers_name', 'details']].head())

# %%
talk_content = ['Aakash Odedra\dance hurricane paper wind light music applause']
recommend_talks(talk_content)
# Out:
#          speakers_name                                            details
# 0        Aakash Odedra    dance hurricane paper wind light music applause
# 3806   Quixotic Fusion  dancing light music applause music applause mu...
# 4080   Ryan Heffington  dance unleash inner joy  thank you cheers appl...
# 842   Chinyanta Kabaso  dazzling diversity african dance  14 moves rhy...
# 690   Bruno Maisonnier  dance tiny robots mechanical noises music appl...

# %%
dataset.loc[0]
# Out:
# mongodb_id                                          652af294d95841780141bab7
# has_preview                                                            False
# shortened_url                                        https://go.ted.com/6Ryx
# comments_enabled                                                       False
# comments_logged_in_only                                                False
# talk_id                                                                 2147
# talk_slug                  aakash_odedra_a_dance_in_a_hurricane_of_paper_...
# talk_title                   A dance in a hurricane of paper, wind and light
# talk_social_title            A dance in a hurricane of paper, wind and light
# speakers_name                                                  Aakash Odedra
# recorded_on                                                       2014-10-21
# curator_approved                                                        True
# view_counts                                                           950322
# duration_in_seconds                                                      580
# published_timestamp                                     2014-12-05T16:00:35Z
# talk_description           Choreographer Aakash Odedra is dyslexic and ha...
# talk_social_description    Choreographer Aakash Odedra is dyslexic and ha...
# video_context                                                 TEDGlobal 2014
# video_audio_language                                                      en
# video_data_language                                                       en
# has_translations                                                        True
# is_featured                                                             True
# video_type_id                                                              1
# video_type_name                                               TED Stage Talk
# video_speakers_typename                                AcmeSpeakerConnection
# topic_0_id                                                                40
# topic_0_name                                                           music
# transcript                                                (Music) (Applause)
# transcript_language                                                  English
# topic_1_id                                                              41.0
# topic_1_name                                                     performance
# topic_2_id                                                              94.0
# topic_2_name                                                           dance
# topic_3_id                                                               NaN
# topic_3_name                                                             NaN
# topic_4_id                                                               NaN
# topic_4_name                                                             NaN
# topic_5_id                                                               NaN
# topic_5_name                                                             NaN
# topic_6_id                                                               NaN
# topic_6_name                                                             NaN
# topic_7_id                                                               NaN
# topic_7_name                                                             NaN
# related_talk_0_slug                the_lxd_in_the_internet_age_dance_evolves
# related_talk_0_id                                                      786.0
# related_talk_1_slug                           pilobolus_a_dance_of_symbiosis
# related_talk_1_id                                                       24.0
# related_talk_2_slug                       quixotic_fusion_dancing_with_light
# related_talk_2_id                                                     1464.0
# related_talk_3_slug                             kenichi_ebina_my_magic_moves
# related_talk_3_id                                                      179.0
# related_talk_4_slug        aakash_odedra_a_dance_in_a_hurricane_of_paper_...
# related_talk_4_id                                                     2147.0
# related_talk_5_slug        joey_alexander_an_11_year_old_prodigy_performs...
# related_talk_5_id                                                     2273.0
# speakers_typename                                                AcmeSpeaker
# speakers_firstname                                                    Aakash
# speakers_lastname                                                     Odedra
# speakers_description                                           Choreographer
# speakers_is_live                                                        True
# speakers_who_they_are      Aakash Odedra sets raw ancient dance forms fro...
# speakers_why_listen        Based in the UK with a growing international r...
# external_service                                                     YouTube
# external_service_code                                            T49IjKho5y8
# Name: 0, dtype: object

# %%
talk_content = ['Aala El-Khani\What it\'s like to be a parent in a war zone W']
recommend_talks(talk_content)
# Out:
#         speakers_name                                            details
# 1385  Eduardo Briceño  get better things care us go life trying best ...
# 161      Alex Honnold  climbed 3000foot vertical cliff  without ropes...
# 2669       Keith Lowe  need stop obsessing world war ii hello everybo...
# 1893   Heidi M. Sosik  discoveries awaiting us oceans twilight zone b...
# 3804      P.W. Singer  military robots future war thought id begin sc...

# %%
dataset.loc[1]
# Out:
# mongodb_id                                          652af54dd95841780141bab8
# has_preview                                                            False
# shortened_url                                        https://go.ted.com/6sZX
# comments_enabled                                                       False
# comments_logged_in_only                                                False
# talk_id                                                                 2683
# talk_slug                  aala_el_khani_what_it_s_like_to_be_a_parent_in...
# talk_title                       What it's like to be a parent in a war zone
# talk_social_title                What it's like to be a parent in a war zone
# speakers_name                                                  Aala El-Khani
# recorded_on                                                       2016-02-14
# curator_approved                                                        True
# view_counts                                                          1237721
# duration_in_seconds                                                      846
# published_timestamp                                     2017-02-10T15:49:37Z
# talk_description           How do parents protect their children and help...
# talk_social_description    How do parents protect their children and help...
# video_context                                                 TEDxManchester
# video_audio_language                                                      en
# video_data_language                                                       en
# has_translations                                                        True
# is_featured                                                             True
# video_type_id                                                              2
# video_type_name                                                    TEDx Talk
# video_speakers_typename                                AcmeSpeakerConnection
# topic_0_id                                                                74
# topic_0_name                                                      psychology
# transcript                  Worldwide, over 1.5 billion people experience...
# transcript_language                                                  English
# topic_1_id                                                              86.0
# topic_1_name                                                   communication
# topic_2_id                                                              87.0
# topic_2_name                                                       community
# topic_3_id                                                             100.0
# topic_3_name                                                       parenting
# topic_4_id                                                             105.0
# topic_4_name                                                             war
# topic_5_id                                                             180.0
# topic_5_name                                                natural disaster
# topic_6_id                                                             198.0
# topic_6_name                                                        violence
# topic_7_id                                                             199.0
# topic_7_name                                                        humanity
# related_talk_0_slug        anders_fjellberg_two_nameless_bodies_washed_up...
# related_talk_0_id                                                     2353.0
# related_talk_1_slug        melissa_fleming_a_boat_carrying_500_refugees_s...
# related_talk_1_id                                                     2358.0
# related_talk_2_slug        alexander_betts_our_refugee_system_is_failing_...
# related_talk_2_id                                                     2449.0
# related_talk_3_slug        luma_mufleh_don_t_feel_sorry_for_refugees_beli...
# related_talk_3_id                                                     2809.0
# related_talk_4_slug        melanie_nezer_the_fundamental_right_to_seek_as...
# related_talk_4_id                                                    45969.0
# related_talk_5_slug        muhammed_idris_what_refugees_need_to_start_new...
# related_talk_5_id                                                    36063.0
# speakers_typename                                                AcmeSpeaker
# speakers_firstname                                                      Aala
# speakers_lastname                                                   El-Khani
# speakers_description                               Humanitarian psychologist
# speakers_is_live                                                        True
# speakers_who_they_are      Aala El-Khani explores the needs of families a...
# speakers_why_listen        <p>Dr. Aala El-Khani researches and develops i...
# external_service                                                     YouTube
# external_service_code                                            dY9f9bFctUE
# Name: 1, dtype: object
